# %% [markdown]
# # 정렬
# ## index이름, column 이름을 기준으로 정렬
#
# - <b style='font-size:1.2em'>sort_index(axis, ascending=True)</b>
#     - axis
#         - index 이름 기준 정렬(행) : 'index' 또는 0 (기본값)
#         - column 이름 기준 정렬(열) : 'columns' 또는 1
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
import pandas as pd

df = pd.read_csv('saved_data/movie.csv',index_col='movie_title') #index_col을 하는 것을 잊지 말자!

# %%
df.sort_index() #오름차순정렬이다.
#(1)과 같이 적으면 정렬 기준을 바꿀 수 있다.
# Out:
#                             color        director_name  \
# movie_title
# #Horror                     Color         Tara Subkoff
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                   NaN  Christopher Barnard
# ...                           ...                  ...
# [Rec] 2                     Color      Jaume Balagueró
# eXistenZ                    Color     David Cronenberg
# xXx                         Color            Rob Cohen
# xXx: State of the Union     Color         Lee Tamahori
# Æon Flux                    Color         Karyn Kusama
#
#                             num_critic_for_reviews  duration  \
# movie_title
# #Horror                                       35.0     101.0
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# ...

# %%
#컬럼 이름을 기준으로 정렬----위의 것과의 차이점을 느껴라.

df.sort_index(axis=1)
df.sort_index(axis='columns')
# Out:
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# ...                                                            ...
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             946.0
# My Date with Drew                                             86.0
#
#                                                actor_1_name  \
# movie_title
# Avatar                                          CCH Pounder
# ...

# %%
df.loc['Spectre':'John Carter']
# Out:
#                                             color      director_name  \
# movie_title
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# John Carter                                 Color     Andrew Stanton
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
# John Carter                                                  462.0     132.0
#
#                                             director_facebook_likes  \
# movie_title
# Spectre                                                         0.0
# ...

# %%
df2 = df.sort_index()

# %%
df2.loc['A':'C'] #이렇게 하면, A로 시작하는 거에서부터 C로 시작하는거 바로 이전의 것까지 잘 출력해준다.
#이런 식으로 , 특정 글자로 시작하는 이름으로 조회가 가능하다.
# Out:
#                                               color         director_name  \
# movie_title
# A Beautiful Mind                              Color            Ron Howard
# A Beginner's Guide to Snuff                   Color      Mitchell Altieri
# A Better Life                                 Color           Chris Weitz
# A Bridge Too Far                    Black and White  Richard Attenborough
# A Bug's Life                                  Color         John Lasseter
# ...                                             ...                   ...
# But I'm a Cheerleader                         Color          Jamie Babbit
# Butch Cassidy and the Sundance Kid            Color       George Roy Hill
# Butterfly                                     Color           Matt Cimber
# Butterfly Girl                                Color             Cary Bell
# By the Sea                                    Color   Angelina Jolie Pitt
#
# ...

# %%
df2.sort_index().loc['A':'B'] #a로 시작하는 놈만 조회한다.
# Out:
#                                        color         director_name  \
# movie_title
# A Beautiful Mind                       Color            Ron Howard
# A Beginner's Guide to Snuff            Color      Mitchell Altieri
# A Better Life                          Color           Chris Weitz
# A Bridge Too Far             Black and White  Richard Attenborough
# A Bug's Life                           Color         John Lasseter
# ...                                      ...                   ...
# Avatar                                 Color         James Cameron
# Avengers: Age of Ultron                Color           Joss Whedon
# Awake                                  Color           Joby Harold
# Away We Go                             Color            Sam Mendes
# Ayurveda: Art of Being                 Color             Pan Nalin
#
#                              num_critic_for_reviews  duration  \
# movie_title
# A Beautiful Mind                              205.0     135.0
# ...

# %%
#행정렬. 정렬기준은 컬럼의 값이다.
#director_name을 기준으로 오름차순/내림차순 행정렬을 한다.
df2.sort_values(by="director_name",ascending=False)

#문자를 기준으로 정렬을 할 때, 가장 먼저 나오는 것은 특수문자이고, 그 다음은 숫자-----대/소문자 순이다.
# Out:
#                          color       director_name  num_critic_for_reviews  \
# movie_title
# Bizarre                  Color       Étienne Faure                     9.0
# Sur le seuil             Color        Éric Tessier                     9.0
# Mambo Italiano           Color    Émile Gaudreault                    67.0
# The Oxford Murders       Color  Álex de la Iglesia                    71.0
# Along the Roadside       Color       Zoran Lisinac                    17.0
# ...                        ...                 ...                     ...
# War & Peace              Color                 NaN                    10.0
# Wings                    Color                 NaN                    19.0
# Wolf Creek               Color                 NaN                     2.0
# Wuthering Heights        Color                 NaN                     9.0
# Yu-Gi-Oh! Duel Monsters  Color                 NaN                     6.0
#
# ...

# %%
df.sort_values('duration').head(10)
# Out:
#                                       color        director_name  \
# movie_title
# The Touch                             Color           Jane Clark
# Shaun the Sheep                       Color                  NaN
# Robot Chicken                         Color                  NaN
# Vessel                                Color          Clark Baker
# Wal-Mart: The High Cost of Low Price  Color     Robert Greenwald
# Sabrina, the Teenage Witch            Color                  NaN
# Anger Management                      Color                  NaN
# It's Always Sunny in Philadelphia     Color                  NaN
# Home Movies                           Color                  NaN
# 10,000 B.C.                             NaN  Christopher Barnard
#
#                                       num_critic_for_reviews  duration  \
# movie_title
# The Touch                                                NaN       7.0
# Shaun the Sheep                                         12.0       7.0
# ...

# %%
df.sort_values(['duration','imdb_score'])[['duration','imdb_score']].head(20) #duration을 기준으로 먼저 정렬하고, 그 다음에 imdb_score을 기준으로 정렬한다.
#코드가 약간 복잡하다. 복습 철저!!
# Out:
#                                       duration  imdb_score
# movie_title
# The Touch                                  7.0         5.2
# Shaun the Sheep                            7.0         8.3
# Robot Chicken                             11.0         7.8
# Vessel                                    14.0         6.2
# Wal-Mart: The High Cost of Low Price      20.0         6.8
# Sabrina, the Teenage Witch                22.0         6.6
# Anger Management                          22.0         6.7
# 10,000 B.C.                               22.0         7.2
# Rules of Engagement                       22.0         7.3
# Strangers with Candy                      22.0         8.1
# Home Movies                               22.0         8.2
# It's Always Sunny in Philadelphia         22.0         8.8
# Sonny with a Chance                       23.0         6.1
# Star Wars: The Clone Wars                 23.0         7.9
# Yu-Gi-Oh! Duel Monsters                   24.0         7.0
# ...

# %%
#일부는 오름차순을 하고 일부는 내림차순을 하기 위해서는.....

df.sort_values(['duration','imdb_score'],ascending=[True,False])[['duration','imdb_score']].head(20) #duration을 기준으로 먼저 정렬하고, 그 다음에 imdb_score을 기준으로 정렬한다.
#duration은 오름차순으로 하는 것이고 imdb_score는 내림차순으로 하겠다는 것이다.

#위의 코드를 설정을 하고, duration과 imdb_score의 ascending 차이를 잘 보자.
# Out:
#                                       duration  imdb_score
# movie_title
# Shaun the Sheep                            7.0         8.3
# The Touch                                  7.0         5.2
# Robot Chicken                             11.0         7.8
# Vessel                                    14.0         6.2
# Wal-Mart: The High Cost of Low Price      20.0         6.8
# It's Always Sunny in Philadelphia         22.0         8.8
# Home Movies                               22.0         8.2
# Strangers with Candy                      22.0         8.1
# Rules of Engagement                       22.0         7.3
# 10,000 B.C.                               22.0         7.2
# Anger Management                          22.0         6.7
# Sabrina, the Teenage Witch                22.0         6.6
# Star Wars: The Clone Wars                 23.0         7.9
# Sonny with a Chance                       23.0         6.1
# Lovesick                                  24.0         7.9
# ...

# %%
result = df.query('duration > 250').sort_values("duration")
#이런 식으로,쿼리문과 sort_values문을 합쳐서 쓸 수 있다. 
#한 코드에 여러개의 메소드를 적용시켜서, 코드의 길이를 훨씬 더 간단하게 만들 수 있다.

result
# Out:
#                              color         director_name  \
# movie_title
# Cleopatra                    Color  Joseph L. Mankiewicz
# Once Upon a Time in America  Color          Sergio Leone
# Arn: The Knight Templar      Color          Peter Flinth
# Gettysburg                   Color           Ron Maxwell
# Gods and Generals            Color           Ron Maxwell
# The Company                  Color                   NaN
# Apocalypse Now               Color  Francis Ford Coppola
# Das Boot                     Color     Wolfgang Petersen
# The Legend of Suriyothai     Color   Chatrichalerm Yukol
# Heaven's Gate                Color        Michael Cimino
# Blood In, Blood Out          Color       Taylor Hackford
# Carlos                       Color                   NaN
# Trapped                      Color                   NaN
#
#                              num_critic_for_reviews  duration  \
# movie_title
# Cleopatra                                      72.0     251.0
# ...

# %%
df['color'].value_counts().sort_index() #이런 식으로 해도 괘안타.
# Out:
# Black and White     204
# Color              4693
# Name: color, dtype: int64

# %%
df['color'].value_counts().sort_values()
# Out:
# Black and White     204
# Color              4693
# Name: color, dtype: int64

# %% [markdown]
# ## 특정 컬럼(열)의 값을 기준으로 정렬
# - <b style='font-size:1.2em'>sort_values(by, ascending, inplace)</b>
#     - by
#         - **정렬 기준 컬럼이름**을 문자열로 지정
#         - 여러 컬럼에 대해 정렬할 경우 리스트에 담아 전달
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#         - 여러 컬럼에 대해 정렬할 경우 정렬방식도 리스트에 담아 전달
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경
#     - 결측치는 방식과 상관없이 마지막에 나온다.

# %% [markdown]
# # flights.csv (항공기 운항 기록 데이터)
# - MONTH : 비행 월
# - DAY : 비행 일
# - WEEKDAY : 비행 요일 - 1(월요일)~7(일요일)
# - AIRLINE : 항공사 코드
#      - UA:	United Air Lines Inc.
#      - AA:	American Airlines Inc.
#      - US:	US Airways Inc.
#      - F9:	Frontier Airlines Inc.
#      - B6:	JetBlue Airways
#      - OO:	Skywest Airlines Inc.
#      - AS:	Alaska Airlines Inc.
#      - NK:	Spirit Air Lines
#      - WN:	Southwest Airlines Co.
#      - DL:	Delta Air Lines Inc.
#      - EV:	Atlantic Southeast Airlines
#      - HA:	Hawaiian Airlines Inc.
#      - MQ:	American Eagle Airlines Inc.
#      - VX:	Virgin America
# - ORG_AIR : 출발공항
# - DEST_AIR : 도착공항
# - SCHED_DEP : 출발예정시각
# - DEP_DELAY : 출발지연시간(분)
# - AIR_TIME : 비행시간(분)
# - DIST : 비행거리(마일)
# - SCHED_ARR : 도착예정시각
# - ARR_DELAY : 도착지연시간(분)
# - DIVERTED : 회항여부(1: True, 0: False)
# - CANCELLED : 취소여부(1: True, 0: False)

# %%
import pandas as pd


flight = pd.read_csv("saved_data/flights.csv")

# %%
#사전에 정보들을 확인해본다.

flight.info()


#참고로, 월요일 화요일 등을 표시하는 것의 dtype이 int인 경우도 있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
flight.isnull().sum()
# Out:
# MONTH           0
# DAY             0
# WEEKDAY         0
# AIRLINE         0
# ORG_AIR         0
# DEST_AIR        0
# SCHED_DEP       0
# DEP_DELAY     833
# AIR_TIME     1018
# DIST            0
# SCHED_ARR       0
# ARR_DELAY    1018
# DIVERTED        0
# CANCELLED       0
# dtype: int64

# %%
flight.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %% [markdown]
# # 기술통계 메소드들을 이용한 데이터 집계
# ## 주요 기술통계 메소드
#
# |함수|설명|
# |-|-|
# |**sum()**|합계|
# |**mean()**|평균|
# |**median()**|중위수|
# |**mode()**|최빈값|
# |**quantile()**|분위수|
# |**std()**|표준편차|
# |**var()**|분산|
# |**count()**|결측치를 제외한 원소 개수|
# |**min()**|최소값|
# |**max()**|최대값|
# |**idxmax()**|최대값 index|
# |**idxmin()**|최소값 index|
# |**unique()**|고유값|
# |**nunique()**|고유값의 개수|
#
# <center><b style='font-size:1.2em'>cf) value_counts()는 Series에만 사용할 수 있다.</b></center>

# %% [markdown]
# - DataFrame에 위의 기술 통계 메소드들을 적용할 경우 **컬럼별로 계산한다.**
# - sum(), mode(), max(), min(), unique(), nunique(), count()는 **문자열에 적용가능하다.**
#     - idxmax(), idxmin() 는 문자열 컬럼에 사용할 수 없다. (문자열의 경우 넘파이의 argmax(), argmin() 함수를 사용한다.)

# %% [markdown]
# - **공통 매개변수**
#     - skipna=True(기본값)
#         - 결측치(NA)를 포함해서 계산할지 여부 설정.
#         - True가 기본값으로 결측치(NA)를 제외하고 처리한다.
#         - 결측치 제외하지 않으려면 skipna=False로 설정하는데 결측치가 있으면 결과는 결측치가 된다.
#     - axis
#         - DataFrame에 적용할 때 계산방향을 설정
#             - 0 또는 'index' (기본값): 컬럼 방향으로 집계
#             - 1 또는 'columns': 행 방향으로 집계

# %%
flight
#movie 보다는 data가 훨씬 더 많은 형태이다.
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4      WN     LAX      SLC       1625       58.0
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
#최빈값을 구한다.
flight.mode()
#7월이 가장 많고, 20일이 가장 많고..... 뭐 이런 식이다.
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      7   20        1      DL     ATL      LAX        600       -3.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      59.0   337       2100       -9.0         0          0

# %%
#평균을 구하는데, 되는 경우가 있고 안되는 경우가 있다.
#이유를 자세히 생각하면 간단한데, mean 메소드는 숫자만 계산을 해야 하기 때문이다.
#그래서, 숫자만 계산하기 위해서는 numeric_only 같은 코드를 작성해야 한다.



#numeric_True을 쓰면 오류가 나지 않는다는 것을 알 수 있다.
flight.mean(numeric_only=True)
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# AIR_TIME      115.928576
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY       5.812315
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
flight.sum()
#문자들은 합치면 겁나 웃기게 나온닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Out:
# MONTH                                                   363858
# DAY                                                     918447
# WEEKDAY                                                 229690
# AIRLINE      WNUAMQAAWNUAAAF9AAUAMQEVOOEVUAAAOONKMQWNWNUAOO...
# ORG_AIR      LAXDENDFWDFWLAXIAHDFWSFOORDIAHDFWORDORDORDIAHD...
# DEST_AIR     SLCIADVPSDCAMCISANMSYPHXSTLSJCDROJANMSPCMHINDD...
# SCHED_DEP                                             81186009
# DEP_DELAY                                             629705.0
# AIR_TIME                                             6662879.0
# DIST                                                  51057671
# SCHED_ARR                                             90627495
# ARR_DELAY                                             334057.0
# DIVERTED                                                   137
# CANCELLED                                                  881
# dtype: object

# %%
flight.sum(numeric_only=True)#이렇게 하면 숫자만 출력할 수 있다.

#numeric_only 메소드는 매우 유용한 메소드이므로 이를 잘 파악하는 것이 좋다.
# Out:
# MONTH          363858.0
# DAY            918447.0
# WEEKDAY        229690.0
# SCHED_DEP    81186009.0
# DEP_DELAY      629705.0
# AIR_TIME      6662879.0
# DIST         51057671.0
# SCHED_ARR    90627495.0
# ARR_DELAY      334057.0
# DIVERTED          137.0
# CANCELLED         881.0
# dtype: float64

# %%
#아니면, 이렇게 해도 된다.

flight[['DEP_DELAY','ARR_DELAY']].sum() #컬럼을 선택한 후에 집계한다.
# Out:
# DEP_DELAY    629705.0
# ARR_DELAY    334057.0
# dtype: float64

# %%
#다른 코드.

flight[['MONTH','DAY','WEEKDAY']].mode() #각 컬럼의 최빈값을 보는데, 보고 싶은 것만 보는 코드. 
flight.select_dtypes(include='object').mode() #자료형이 object인 것만 최빈값을 보고 싶을 때 보는 코드.
# Out:
#   AIRLINE ORG_AIR DEST_AIR
# 0      DL     ATL      LAX

# %%
#결측치가 있는 경우, 결과는 결측치이다.

flight.mean(numeric_only=True,skipna=False)
#결측치가 있는 경우 결과는 nan이다.
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY            NaN
# AIR_TIME             NaN
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY            NaN
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %% [markdown]
# ## aggregate(func, axis=0, \*args, \*\*kwargs) 또는 agg(func, axis=0, \*args, \*\*kwargs)
#
# - 밑의 것들은 예시들을 다 잘 파악하게 되면 저절로 이해가 갈 것이다.
# - DataFrame, Series의 메소드로 **집계결과를 다양한 형태로 묶어서 볼 때** 사용한다.
#     - **사용자 정의 집계메소드를 사용할 때도 편리하다.**
# - **매개변수**
#     - func
#         - 집계 함수 지정
#             - 함수명/함수리스트 (문자열)
#                 - 판다스 제공 집계메소드들은 문자열로, 사용자정의 집계함수는 함수 객체로 전달
#             - Dictionary : {'집계할컬럼' : 집계함수, ... }
#                 - 컬럼별로 다른 집계를 할 경우
#     - axis
#         - DataFrame에 적용할 때 0 방향으로 계산할 지 1 방향으로 계산할지 설정
#             - 0 또는 'index' (기본값): 컬럼 방향으로 집계
#             - 1 또는 'columns': 행 방향으로 집계
#     - \*args, \*\*kwargs
#         - 함수에 전달할 매개변수.
#         - 집계함수는 첫번째 매개변수로 Series를 받는다. 그 이외의 매개변수가 있는 경우.

# %%
#판다스가 제공하는 집계 메소드를 사용할 경우 함수명을 문자열로 지정.
flight["ARR_DELAY"].agg(["min","max"]) #agg을 써도 좋고 aggregate을 적어도 좋다.
#이런 식으로 여러개의 데이터를 한번에 사용이 가능하다.
# Out:
# min     -60.0
# max    1185.0
# Name: ARR_DELAY, dtype: float64

# %%
#평균과 함께, 분산이나 표준편자를 같이 보는 것도 좋다.


#도착 딜레이 시간에 대한 여러가지 통계값을 알아 볼 수 있다.
flight['ARR_DELAY'].agg(["mean","std","var"])
# Out:
# mean       5.812315
# std       38.411948
# var     1475.477780
# Name: ARR_DELAY, dtype: float64

# %%
flight.agg(["min","max"]).T
# Out:
#             min     max
# MONTH         1      12
# DAY           1      31
# WEEKDAY       1       7
# AIRLINE      AA      WN
# ORG_AIR     ATL     SFO
# DEST_AIR    ABE     YUM
# SCHED_DEP     5    2359
# DEP_DELAY -24.0  1194.0
# AIR_TIME    8.0   577.0
# DIST         67    4502
# SCHED_ARR     1    2359
# ARR_DELAY -60.0  1185.0
# DIVERTED      0       1
# CANCELLED     0       1

# %%
flight[['DEP_DELAY','ARR_DELAY']].agg(['mean','std']) #이런 식으로 통계값을 구할 수도 있다.
# Out:
#       DEP_DELAY  ARR_DELAY
# mean  10.921192   5.812315
# std   36.146210  38.411948

# %%
flight.select_dtypes(include='int64')
# Out:
#        MONTH  DAY  WEEKDAY  SCHED_DEP  DIST  SCHED_ARR  DIVERTED  CANCELLED
# 0          1    1        4       1625   590       1905         0          0
# 1          1    1        4        823  1452       1333         0          0
# 2          1    1        4       1305   641       1453         0          0
# 3          1    1        4       1555  1192       1935         0          0
# 4          1    1        4       1720  1363       2225         0          0
# ...      ...  ...      ...        ...   ...        ...       ...        ...
# 58487     12   31        4        515  1464       1045         0          0
# 58488     12   31        4       1910   414       2050         0          0
# 58489     12   31        4       1846   262       1956         0          0
# 58490     12   31        4        525   907        855         0          0
# 58491     12   31        4        859   522       1146         0          0
#
# [58492 rows x 8 columns]

# %%
#수치형 --->float,int ====>number


#수치형만 보고 싶고, 그것들에 대한 여러 통계값들을 보고 싶을 때 쓰는 코드이다.

flight.select_dtypes(include='number').agg(['min','max','mean']).T
# Out:
#             min     max         mean
# MONTH       1.0    12.0     6.220646
# DAY         1.0    31.0    15.702096
# WEEKDAY     1.0     7.0     3.926862
# SCHED_DEP   5.0  2359.0  1387.984836
# DEP_DELAY -24.0  1194.0    10.921192
# AIR_TIME    8.0   577.0   115.928576
# DIST       67.0  4502.0   872.900072
# SCHED_ARR   1.0  2359.0  1549.399832
# ARR_DELAY -60.0  1185.0     5.812315
# DIVERTED    0.0     1.0     0.002342
# CANCELLED   0.0     1.0     0.015062

# %%
#컬럼별로 다른 집계를 계산하고 싶은 경우
#{"컬럼명":"집계메소드이름"}

d = {
    "DEP_DELAY":"mean",
    "ARR_DELAY":["min","max"]
    
}


#이런 식으로 바로 넣는다.
flight.agg(d)
# Out:
#       DEP_DELAY  ARR_DELAY
# mean  10.921192        NaN
# min         NaN      -60.0
# max         NaN     1185.0

# %%
#사용저 정의 집계 함수.
#컬럼의 최대값과 최소값 간의 차이를 계산한다.
##파라미터:집계하려는 series ->column(필수인 부분이다.)

def min_max_diff(column):
    """
    Series의 최소값과 최대값의 차이를 계산하는 집계함수.
    [parameter]
        column: pd.Series - 집계할 대상 Series
    [return]
        float: max - min 결과. 문자열컬럼일 경우 none을 반환.
        
    [raise]
        문자열컬럼일 경우 xxx exception 발생
    """
    if column.dtype == "object" or column.dtype == "str":
        return None
    return column.max() - column.min()

# %%
#출력.

min_max_diff(flight['ARR_DELAY'])
# Out:
# 1245.0

# %%
flight['ARR_DELAY'].agg(min_max_diff)
# Out:
# 1245.0

# %%
flight['ARR_DELAY'].agg(["min","max",min_max_diff]) #이런 식으로도 min_max_diff을 볼 수 있다.
# Out:
# min              -60.0
# max             1185.0
# min_max_diff    1245.0
# Name: ARR_DELAY, dtype: float64

# %% [markdown]
# # Groupby
# - 특정 열을 기준으로 같은 값을 가지는 행끼리 묶어서 group화 한다.
# - **~~ 별 집계를 할 때** 사용한다. (성별, 직급별, 등급별 ...)
#     - Group으로 묶을 기준 열은 범주형타입(category)을 사용한다.
# - **구문**
#     - `DF.groupby('그룹으로묶을기준컬럼')`
#         - DataFrameGroupby 객체를 반환한다.
#         - DataFrameGroupby 객체는 어떤 행끼리 묶여있는지 정보를 가진다. 이 객체의 집계함수를 사용하면 그룹별 집계를 할 수 있다.
#             - `DataFrameGroupby객체['집계할 컬럼'].집계함수()`
#         - groupby에 여러개의 컬럼을 기준으로 나눌 경우 리스트에 묶어서 전달한다.
#         - 집계할 컬럼이 여러개인 경우 리스트로 묶어준다.
#     - 집계함수
#         - 기술통계 함수들
#         - agg()/aggregate()
#             - 여러 다른 집계함수 호출시(여러 집계를 같이 볼경우)
#             - 사용자정의 집계함수 호출시
#             - 컬럼별로 다른 집계함수들을 호출할 경우

# %%
#groupby는 ~별 ~의 평균을 구할 때 쓰인다.

flight['AIRLINE'].value_counts()
# Out:
# DL    10601
# AA     8900
# WN     8418
# UA     7792
# OO     6588
# EV     5858
# MQ     3471
# US     1615
# NK     1516
# F9     1317
# VX      993
# AS      768
# B6      543
# HA      112
# Name: AIRLINE, dtype: int64

# %%
flight['ARR_DELAY'].mean()
# Out:
# 5.812315133799631

# %%
#sql에서의 groupby처럼 쓰는 것이다.

gb = flight.groupby("AIRLINE")
print(type(gb)) #DataFrameGroupBy로 리턴을 한다.

gb.groups #그냥 어떻게 묶였느냐 확인하는 것이다.
#자세히 보면, AA를 가지고 있는 놈끼리 묶고, AS를 가지고 있는 놈끼리 묶고 뭐 이런 식이다.
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# ...

# %%
#항공사별 도착지연시간의 평균?
#위의 문제는 문제를 차근차근 뜯어보면 그 코드를 간단히 작성할 수 있다.
flight.groupby("AIRLINE")["ARR_DELAY"].mean()
# Out:
# AIRLINE
# AA     5.542661
# AS    -0.833333
# B6     8.692593
# DL     0.339691
# EV     7.034580
# F9    13.630651
# HA     4.972973
# MQ     6.860591
# NK    18.436070
# OO     7.593463
# UA     7.765755
# US     1.681105
# VX     5.348884
# WN     6.397353
# Name: ARR_DELAY, dtype: float64

# %%
flight.groupby("AIRLINE").mean(numeric_only=True)
# Out:
#             MONTH        DAY   WEEKDAY    SCHED_DEP  DEP_DELAY    AIR_TIME  \
# AIRLINE
# AA       6.661461  15.570562  3.986966  1340.140449  11.274057  144.259404
# AS       6.197917  15.247396  3.941406  1418.269531   1.808594  147.845052
# B6       6.368324  15.788214  4.040516  1512.924494  14.287823  209.412963
# DL       6.277332  15.721158  3.913310  1426.563154   7.242450  115.334187
# EV       6.003926  15.866166  3.927450  1415.510413   9.092625   68.964016
# F9       6.401670  15.914958  4.007593  1407.121488  14.310398  127.592337
# HA       5.508929  15.526786  3.750000   959.419643   2.571429  338.288288
# MQ       5.970614  15.598963  3.902622  1432.251801  11.094323   61.318346
# NK       6.602243  15.680739  4.006596  1336.634565  19.514401  135.736878
# OO       6.134791  15.651943  3.923345  1426.486794   9.662279   76.010272
# UA       6.322510  15.697510  3.871535  1357.970739  16.210485  155.650521
# ...

# %%
#항공사별 출발/도착 지연시간의 평균
###df.groupby()[집계할 컬럼].집계메소드

flight.groupby("AIRLINE")[["DEP_DELAY","ARR_DELAY"]].mean()
# Out:
#          DEP_DELAY  ARR_DELAY
# AIRLINE
# AA       11.274057   5.542661
# AS        1.808594  -0.833333
# B6       14.287823   8.692593
# DL        7.242450   0.339691
# EV        9.092625   7.034580
# F9       14.310398  13.630651
# HA        2.571429   4.972973
# MQ       11.094323   6.860591
# NK       19.514401  18.436070
# OO        9.662279   7.593463
# UA       16.210485   7.765755
# US        4.361355   1.681105
# VX        8.918946   5.348884
# WN       12.639366   6.397353

# %%
#월, 요일별 도착 지연 시간의 평균을 구하자. ----->groupby로 묶을 기준컬럼이 2개이상이다.
#뭐 그렇게 어려울 것은 없다.
result=flight.groupby(["MONTH","WEEKDAY"])['ARR_DELAY'].mean()
result
# Out:
# MONTH  WEEKDAY
# 1      1          12.202723
#        2           3.615756
#        3           2.478328
#        4           6.715006
#        5           6.082635
#                     ...
# 12     3          10.780822
#        4           3.693069
#        5           1.754947
#        6           4.962775
#        7           8.437898
# Name: ARR_DELAY, Length: 77, dtype: float64

# %%
#출발 공항별 출발지연시간의 최솟값,최댓값을 구하도록 하자.
#min,max 둘 다 구해야 하기 때문에, agg 함수를 쓴다.

#복습 철저!! 중요한 구문이다.
flight.groupby("ORG_AIR")["ARR_DELAY"].agg(['min','max',min_max_diff])
# Out:
#           min     max  min_max_diff
# ORG_AIR
# ATL     -57.0   692.0         749.0
# DEN     -44.0  1185.0        1229.0
# DFW     -45.0   839.0         884.0
# IAH     -47.0   858.0         905.0
# LAS     -52.0   732.0         784.0
# LAX     -58.0   725.0         783.0
# MSP     -53.0   474.0         527.0
# ORD     -52.0   531.0         583.0
# PHX     -60.0   551.0         611.0
# SFO     -51.0   682.0         733.0

# %%
flight.groupby('ORG_AIR').agg({"DEP_DELAY":"mean","ARR_DELAY":"min"})
#이런 식으로도 값을 설정할 수 있다.
# Out:
#          DEP_DELAY  ARR_DELAY
# ORG_AIR
# ATL       9.267446      -57.0
# DEN      11.052586      -44.0
# DFW      11.593030      -45.0
# IAH      11.821255      -47.0
# LAS      10.792156      -52.0
# LAX      10.961690      -58.0
# MSP       7.206256      -53.0
# ORD      14.760098      -52.0
# PHX       8.502841      -60.0
# SFO      11.028730      -51.0

# %% [markdown]
# ##  복수열 기준 그룹핑
# - 두개 이상의 열을 그룹으로 묶을 수 있다.
# - groupby의 매개변수에 그룹으로 묶을 컬럼들의 이름을 리스트로 전달한다.

# %% [markdown]
# ## Group 별 집계결과에서 특정 조건의 항목만 조회
# - Groupby 집계 후 boolean indexing 처리한다.

# %%
#항공사별 (출발) 취소 건수

flight['CANCELLED'].value_counts() #결측치가 아닌 값의 개수
flight['CANCELLED'].sum() #1의 합계
# Out:
# 881

# %%
# 취소 안된 건 건수

(flight['CANCELLED']==0).sum()
# Out:
# 57611

# %%
#항공사별 (출발) 취소 건수
#코드를 짜는 법을 잘 보자. 익숙해지면 쉽다.
flight.groupby("AIRLINE")["CANCELLED"].sum()
# Out:
# AIRLINE
# AA    154
# AS      0
# B6      1
# DL     38
# EV    146
# F9     10
# HA      0
# MQ    152
# NK     25
# OO    142
# UA     93
# US     21
# VX      6
# WN     93
# Name: CANCELLED, dtype: int64

# %%
#다른 조건은 같은데, 취소 건수가 100보다 큰 것을 조회한다.
#복습 철저!!!

result = flight.groupby("AIRLINE")["CANCELLED"].sum()
result2 = result[result>=100]#이런 식으로 넣으면 된다.
#최종적으로 result2를 적으면 된다.

result2
# Out:
# AIRLINE
# AA    154
# EV    146
# MQ    152
# OO    142
# Name: CANCELLED, dtype: int64

# %%
#여러가지 코드

flight.select_dtypes(include="int64").agg("count") #df.agg()
flight['ARR_DELAY'].agg("count") #Series.agg()
flight.groupby('AIRLINE').agg("count")#DataFrameGroupBy.agg()
flight.groupby("AIRLINE")["ARR_DELAY"].agg("count")
# Out:
# AIRLINE
# AA     8720
# AS      768
# B6      540
# DL    10539
# EV     5697
# F9     1305
# HA      111
# MQ     3314
# NK     1486
# OO     6425
# UA     7680
# US     1593
# VX      986
# WN     8310
# Name: ARR_DELAY, dtype: int64

# %%
#사용자 정의 집계함수를 agg() 이용해서 호출

def iqr(src:"집계대상",q1=0.25,q3=0.75):
    """
    iqr(InterQuartuleRange) ------->4분위수에서 3분위 - 1분위를 한 값이다.
    분위수 간의 차이이다.
    
    가운데 값들의 범위를 체크하는 것을 하기도 하고,
    극단적으로 큰 값이나 극단적으로 작은 값을 걸러내기 위해 쓰기도 한다.
    
    
    """
    print(type(src))
    qt1,qt3 = src.quantile(q = [q1,q3])
    return qt3-qt1

# %%
#dataframe.agg(사용자정의함수)
#dataframe의 각 컬럼들을 사용자 정의 함수에 전달하다.
#그렇기 때문에 데이터 타입에 관한 것들이 출력이 된 것이다. 내가 위에서 type을 출력해 달라고 했으니까!!


flight.select_dtypes(include="int64").agg(iqr)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# MONTH        None
# DAY          None
# WEEKDAY      None
# SCHED_DEP    None
# DIST         None
# SCHED_ARR    None
# DIVERTED     None
# CANCELLED    None
# dtype: object

# %%
#SeriesGroupby.agg(사용자정의):Series(컬럼)을 group별로 하나씩 사용자 정의 함수에 전달한다.
flight.groupby("AIRLINE")["ARR_DELAY"].agg(iqr)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# AIRLINE
# AA    None
# AS    None
# B6    None
# DL    None
# EV    None
# F9    None
# HA    None
# MQ    None
# NK    None
# OO    None
# UA    None
# US    None
# VX    None
# WN    None
# Name: ARR_DELAY, dtype: object

# %%
#각 컬럼의 값을 group별로 하나씩 사용자 정의 함수에 전달한다.
#위의 iqr에 대한 정의를 잘 보면, 이게 어떤 식으로 전개가되는지에 대한 이유를 잘 알 수 있다!!
flight.groupby('AIRLINE')[['DEP_DELAY','ARR_DELAY']].agg(iqr)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# ...

# %% [markdown]
# # 사용자 정의 집계함수를 만들어 적용
#
# ## 사용자 정의 집계 함수 정의
# - 매개변수
#     1. Series 또는 DataFrame을 받을 매개변수(필수)
#     2. 필요한 값을 받을 매개변수를 선언한다. (선택)

# %% [markdown]
# ## agg() 를 사용해 사용자 정의 집계 함수 호출
# - DataFrame.agg(func=None, axis=0, \*args, \*\*kwargs)
#     - axis : 사용자 정의 함수에 전달할 값들(Series)의 축 지정
# - Series.agg(func=None, axis=0, \*args, \*\*kwargs)
#     - DataFrame의 agg와 매개변수 구조를 맞추기 위해 axis 지정한다. (kwargs를 이용해 매개변수 전달할 경우 axis는 생략해도 된다. - axis기본값 0을 그냥 쓰면 되므로. - keyword 인자 뒤에 position 인자는 안되서 *args로 값 전달시에는 axis를 지정해야 한다.)
# - DataFrameGroupBy.agg(func, \*args, \*\*kwargs) :
#     - axis 지정안함.
#     - 사용자 함수에 Series를 group 별로 전달한다.
# - SeriesGroupBy.agg(func=None,  \*args, \*\*kwargs)
#     - axis 지정안함
#     - 사용자 함수에 Series를 group 별로 전달한다.
#
# - \*args, \*\*kwargs는 사용자 정의 함수에 선언한 매개변수가 있을 경우 전달할 값을 전달한다.
#     - 키워드 인자를 이용해 가변인자로 전달하는 것이 편하다.

# %% [markdown]
# # TODO

# %%
# 1. data/diamonds.csv 를 읽어 DataFrame 생성

# 2. 1에서 생성한 DataFrame의 정보 조회
#     - 배열의 shape조회
#     - DataFrame에 대한 정보조회
#     - 상/하위 5개 행 조회
#     - 결측치 확인

# 3. carat, price, depth의 합계, 평균, 최대, 최소 조회

# 4. price는 최대, 최소, color는 고유값의 개수를 조회

# 5. cut의 고유값별 개수를 조회

# 6. cut별 가격 평균 조회

# 7. cut별 가격 평균중 4000이상만 조회

# 8. clarity별 carat 평균과 표준편차 조회

# 9. cut과 color 별로 가격은 평균을 carat은 최대값을 조회 

# 10. 9번 문제의 결과에서 가격의 평균이 5000이상이고 carat의 최대값이 3이상인 결과만 조회
